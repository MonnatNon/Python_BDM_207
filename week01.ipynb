# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %% [markdown]
# # 1. User input and output

# %%
print("Hello World")

# %%
name = "Monnat Saenton"

# %%
name = "Monnat Saenton"
print("Hello" + name + "," + "I'm" + "your" + "father")

# %%
name = "Monnat Saenton"
print("Hello " + name + "," + "I'm" + "your" + "father")

# %%
name = "มนต์นัทธ์ แสนทน"

# %%
name = "มนต์นัทธ์ แสนทน"
print("สวัสดี " + name )

# %%
age = input("What is your age = ")
# Out:
# What is your age =  20

# %%
print(age)
# Out:
# 20

# %%
print("I'm"+ age + "Yearold. ")
# Out:
# I'm20Yearold.

# %%
print("I'm" + "" + age+ ""+ "Yearold. ")
# Out:
# I'm20Yearold.

# %%
print("I'm "+ age + " Yearold. ") # เว้นช่องระหว่างคำ
# Out:
# I'm 20 Yearold.

# %% [markdown]
# # Ex. 1, How to fix this syntax error ------ Problem -----
# tenyears_age = age + 10
# print(tenyears_age)

# %%
tenyears_age = age + 10
print(tenyears_age)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-6-f76064c47559> in <module>
# ----> 1 tenyears_age = age + 10
#       2 print(tenyears_age)
#
# TypeError: can only concatenate str (not "int") to str

# %%
#ตอบคำถาม EX.1 -----Solve
age = int(input('What is your age ='))

#เปลี่ยนตัวแปรที่ Input เข้าไปเป็นรับค่าแบบ Int
# Out:
# What is your age = 20

# %%
tenyears_age = age + 10
print(tenyears_age)
# Out:
# 30

# %% [markdown]
# # Ex. 2, How to fix this syntax error ------ Problem -----
# print("The pi is equal to" + pi)

# %%
pi = 3.14
print(pi)
# Out:
# 3.14

# %%
print("The pi is equal to" + pi)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-16-d28082005652> in <module>
# ----> 1 print("The pi is equal to" + pi)
#
# TypeError: can only concatenate str (not "float") to str

# %%
pi = 3.14
print(pi)
# Out:
# 3.14

# %%
print("The pi is equal to" + str(pi)
# Out:
#   File "<ipython-input-24-50780796e664>", line 1
#     print("The pi is equal to" + str(pi)
#                                         ^
# SyntaxError: unexpected EOF while parsing

# %% [markdown]
# #ตอบคำถาม EX.2 -----Solve-----

# %%
print("The pi is equal to " + str(pi)) 
#เปลี่ยนให้ตัวแปร print ออกมาเป็น String 
#อย่าลืมใส่วงเล็บปิด
# Out:
# The pi is equal to 3.14

# %% [markdown]
# # Ex. 3, How to fix this runtime error ------ Problem -----

# %% [markdown]
# #ตอบคำถาม EX.3 -----Solve-----

# %%
a = input("What is your A = ")
b = input("What is your B = ")
# Out:
# What is your A =  20
# What is your B =  15

# %%
a = int(input("What is your A = "))
b = int(input("What is your B = "))

#แก้โดยการเปลี่ยนให้รับ input เป็นค่า int
# Out:
# What is your A =  20
# What is your B =  15

# %%
c = a + b
print(c)
# Out:
# 35

# %% [markdown]
# # Ex. 4, How to do this? ------ Problem -----

# %%
['Hello', 'World']
# Out:
# ['Hello', 'World']

# %% [markdown]
# #ตอบคำถาม EX.4 -----Solve-----

# %%
a = "Hello Wolrld"
print(a.split())

#ใช้ medthod split ที่เป็นการแยก string ออกจากกันที่จะแสดงผลบน Output
# Out:
# ['Hello', 'Wolrld']

# %% [markdown]
# # #Ex. 5, How to use sort in descending order? ------ Problem -----
# L.sort(...)
# L

# %%
L = [[1,2,3],
     [4,5,6],
     [7,8,9]]
L
# Out:
# [[1, 2, 3], [4, 5, 6], [7, 8, 9]]

# %% [markdown]
# #ตอบคำถาม EX.5 -----Solve-----

# %%
L.sort(reverse=True)
L

#ใช้ medthod Reverse เข้ามาช่วยเพื่อตัวเลขเรียงกลับหลัง
#ข้อนี้ต้องดูซ้ำ
# Out:
# [[7, 8, 9], [4, 5, 6], [1, 2, 3]]

# %% [markdown]
# # 622110207 Monnat Saenton
