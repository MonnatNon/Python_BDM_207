# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %% [markdown]
# # 954471 - MIDTERM EXAMINATION
# **622110207 Monnat Saenton**

# %% [markdown]
# # Part 1

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# **(1) Create a random matrix of size 5 x 5, then change all values in row 3 and column 3 to 0**

# %%
NON = np.random.rand(5,5)
NON[0:,-3] = 0
NON[3,:] = 0

NON
# Out:
# array([[0.71329257, 0.15267155, 0.        , 0.15831625, 0.5139379 ],
#        [0.86475792, 0.32528099, 0.        , 0.51682677, 0.41252132],
#        [0.92907356, 0.07426475, 0.        , 0.9305839 , 0.27213657],
#        [0.        , 0.        , 0.        , 0.        , 0.        ],
#        [0.94837526, 0.2273908 , 0.        , 0.98929021, 0.22759806]])

# %% [markdown]
# **(2)1.2 Create a random matrix of size 4 x 4, then copy all values in column 1 and 2 to column 3 and 4**

# %%
NR = np.random.rand(4,4)
NR_D = NR[:,0:2]
NR_C = np.hstack((NR[:,0:2],NR_D))
NR_C
# Out:
# array([[0.99077711, 0.85641252, 0.99077711, 0.85641252],
#        [0.1756187 , 0.92664111, 0.1756187 , 0.92664111],
#        [0.88487462, 0.94649697, 0.88487462, 0.94649697],
#        [0.42076707, 0.82992865, 0.42076707, 0.82992865]])

# %% [markdown]
# **(23)1.3 Create list of n times of 'x' corresponding to each of the number in your student-id (shorter code, higher score)**
# * ex.
# * id = "4305033"

# %%
id = "622110207"
x = [int(i) * 'x' for i in id]
x
# Out:
# ['xxxxxx', 'xx', 'xx', 'x', 'x', '', 'xx', '', 'xxxxxxx']

# %% [markdown]
# **(4)1.4 Find average number of each number in your student-id (shorter code, higher score)**
# * ex.
# * id = "4305033"
# * 2.5714285714285716

# %%
ID = [6, 2, 2, 1, 1, 0, 2, 0, 7]
avg = sum(ID)/len(ID)
print("The average is ", round(avg,2))
# Out:
# The average is  2.33

# %% [markdown]
# **(5)1.6 Giving n, create this following picture (shorter code, higher score)**¶
# * ex.
# * n = 5

# %%
#คำตอบข้อ 4
n = int(input())   
for x in range(1,n+1):
    print("*" * x)
# Out:
#  5
# *
# **
# ***
# ****
# *****

# %% [markdown]
# **(6)1.7 Giving n, create this following picture (shorter code, higher score)**
# * ex.
# * n = 5

# %%
#คำตอบข้อ 5
n = int(input())  
for x in range(1,n + 1):
  for y in range(6 - x):
    print (" ",end="")
  for y in range(1,x + 1):
    print("*",end="")
  print()
# Out:
#  5
#      *
#     **
#    ***
#   ****
#  *****

# %% [markdown]
# **(7)1.8 Count number of even number and odd number in your student-id (shorter code, higher score)**
# * ex.
# * id = "4305033"
# * 3
# * 4

# %%
ID = [6, 2, 2, 1, 1, 0, 2, 0, 7] 
even, odd = 0, 0
for num in ID:
    if num % 2 == 0: even += 1
    else: odd += 1
                 
print("Number of even numbers : ", even)
print("Number of odd numbers : ", odd)
# Out:
# Number of even numbers :  6
# Number of odd numbers :  3

# %% [markdown]
# **(8)1.10 Calculate the different between this year (64) and your first year of student using your student-id**

# %%
year = "64"
id = "622110207"
int(year) - int(id[0:2])
# Out:
# 2

# %% [markdown]
# **(9)1.11 Use your student-id to plot a bar chart**
# * ex.
# * id = "4305033"

# %%
ID = [6, 2, 2, 1, 1, 0, 2, 0, 7]
data = [6, 2, 2, 1, 1, 0, 2, 0, 7]
plt.bar(ID, data)
plt.show()

# %% [markdown]
# **(10)1.12 Use your student-id to plot a pie chart**
# * ex.
# * id = "4305033"

# %%
ID = [6, 2, 2, 1, 1, 0, 2, 0, 7]
data = [6, 2, 2, 1, 1, 0, 2, 0, 7]

plt.pie(data, labels = ID)
plt.show()

# %% [markdown]
# # PART 2

# %% [markdown]
# **2.1 Please prepare this dataset for create machine learning model https://raw.githubusercontent.com/plenoi/BDM/master/titanic.txt Please Change 4305033 to your student-id (5 Points**

# %%
df = pd.read_csv('https://raw.githubusercontent.com/plenoi/BDM/master/titanic.txt', sep='\t', header = 0)
df = augment(df, 622110207)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-251-486f1ce48b12> in <module>
#       1 df = pd.read_csv('https://raw.githubusercontent.com/plenoi/BDM/master/titanic.txt', sep='\t', header = 0)
# ----> 2 df = augment(df, 622110207)
#
# NameError: name 'augment' is not defined

# %% [markdown]
# **2.2 Use prepared dataset from 2.1 to create machine learning model, then evaluate model performance using Train/Test Accuracy and Confusion Matrix. Note: please compare performance of 3 or more models. (5 Points**

# %%
params = {'C': [2,4,6,8,10,12,14,16]} 
clf = GridSearchCV(LogisticRegression(random_state=0, solver='liblinear'),params, cv=10) 
clf.fit(X_train_norm, y_train)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-268-f500983b087c> in <module>
#       1 params = {'C': [2,4,6,8,10,12,14,16]}
#       2 clf = GridSearchCV(LogisticRegression(random_state=0, solver='liblinear'),params, cv=10)
# ----> 3 clf.fit(X_train_norm, y_train)
#
# NameError: name 'X_train_norm' is not defined
